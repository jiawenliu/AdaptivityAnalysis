# %% [markdown]
# # Image Classification with Convolutional Neural Networks

# %% [markdown]
# ## Install and import dependencies
#
# We'll need [TensorFlow Datasets](https://www.tensorflow.org/datasets/), an API that simplifies downloading and accessing datasets, and provides several sample datasets to work with. We're also using a few helper libraries.

# %%
import tensorflow as tf
# Out:
# 2023-02-27 22:07:52.870051: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Import TensorFlow Datasets
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

# Helper libraries
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# ## Import the Fashion MNIST dataset

# %% [markdown]
# This guide uses the [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset, which contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 $\times$ 28 pixels), as seen here:
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite" width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST samples</a> (by Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Fashion MNIST is intended as a drop-in replacement for the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset—often used as the "Hello, World" of machine learning programs for computer vision. The MNIST dataset contains images of handwritten digits (0, 1, 2, etc) in an identical format to the articles of clothing we'll use here.
#
# This guide uses Fashion MNIST for variety, and because it's a slightly more challenging problem than regular MNIST. Both datasets are relatively small and are used to verify that an algorithm works as expected. They're good starting points to test and debug code.
#
# We will use 60,000 images to train the network and 10,000 images to evaluate how accurately the network learned to classify images. You can access the Fashion MNIST directly from TensorFlow, using the [Datasets](https://www.tensorflow.org/datasets) API:

# %%
dataset, metadata = tfds.load('fashion_mnist', as_supervised=True, with_info=True)
train_dataset, test_dataset = dataset['train'], dataset['test']
# Out:
# 2023-02-27 22:07:59.042639: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Loading the dataset returns metadata as well as a *training dataset* and *test dataset*.
#
# * The model is trained using `train_dataset`.
# * The model is tested against `test_dataset`.
#
# The images are 28 $\times$ 28 arrays, with pixel values in the range `[0, 255]`. The *labels* are an array of integers, in the range `[0, 9]`. These correspond to the *class* of clothing the image represents:
#
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>
#
# Each image is mapped to a single label. Since the *class names* are not included with the dataset, store them here to use later when plotting the images:

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal',      'Shirt',   'Sneaker',  'Bag',   'Ankle boot']

# %% [markdown]
# ### Explore the data
#
# Let's explore the format of the dataset before training the model. The following shows there are 60,000 images in the training set, and 10000 images in the test set:

# %%
num_train_examples = metadata.splits['train'].num_examples
num_test_examples = metadata.splits['test'].num_examples
print("Number of training examples: {}".format(num_train_examples))
print("Number of test examples:     {}".format(num_test_examples))
# Out:
# Number of training examples: 60000
# Number of test examples:     10000

# %% [markdown]
# ## Preprocess the data
#
# The value of each pixel in the image data is an integer in the range `[0,255]`. For the model to work properly, these values need to be normalized to the range `[0,1]`. So here we create a normalization function, and then apply it to each image in the test and train datasets.

# %%
def normalize(images, labels):
  images = tf.cast(images, tf.float32)
  images /= 255
  return images, labels

# The map function applies the normalize function to each element in the train
# and test datasets
train_dataset =  train_dataset.map(normalize)
test_dataset  =  test_dataset.map(normalize)

# The first time you use the dataset, the images will be loaded from disk
# Caching will keep them in memory, making training faster
train_dataset =  train_dataset.cache()
test_dataset  =  test_dataset.cache()

# %% [markdown]
# ### Explore the processed data
#
# Let's plot an image to see what it looks like.

# %%
# Take a single image, and remove the color dimension by reshaping
for image, label in test_dataset.take(1):
  break
image = image.numpy().reshape((28,28))

# Plot the image - voila a piece of fashion clothing
plt.figure()
plt.imshow(image, cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()
# Out:
# 2023-02-27 22:07:59.513463: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2023-02-27 22:07:59.513788: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# Display the first 25 images from the *training set* and display the class name below each image. Verify that the data is in the correct format and we're ready to build and train the network.

# %%
plt.figure(figsize=(10,10))
i = 0
for (image, label) in test_dataset.take(25):
    image = image.numpy().reshape((28,28))
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image, cmap=plt.cm.binary)
    plt.xlabel(class_names[label])
    i += 1
plt.show()
# Out:
# 2023-02-27 22:08:00.254968: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2023-02-27 22:08:00.255069: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# ## Build the model
#
# Building the neural network requires configuring the layers of the model, then compiling the model.

# %% [markdown]
# ### Setup the layers
#
# The basic building block of a neural network is the *layer*. A layer extracts a representation from the data fed into it. Hopefully, a series of connected layers results in a representation that is meaningful for the problem at hand.
#
# Much of deep learning consists of chaining together simple layers. Most layers, like `tf.keras.layers.Dense`, have internal parameters which are adjusted ("learned") during training.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), padding='same', activation=tf.nn.relu,
                           input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2), strides=2),
    tf.keras.layers.Conv2D(64, (3,3), padding='same', activation=tf.nn.relu),
    tf.keras.layers.MaxPooling2D((2, 2), strides=2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %% [markdown]
# This network layers are:
#
# * **"convolutions"** `tf.keras.layers.Conv2D and MaxPooling2D`— Network start with two pairs of Conv/MaxPool. The first layer is a Conv2D filters (3,3) being applied to the input image, retaining the original image size by using padding, and creating 32 output (convoluted) images (so this layer creates 32 convoluted images of the same size as input). After that, the 32 outputs are reduced in size using a MaxPooling2D (2,2) with a stride of 2. The next Conv2D also has a (3,3) kernel, takes the 32 images as input and creates 64 outputs which are again reduced in size by a MaxPooling2D layer. So far in the course, we have described what a Convolution does, but we haven't yet covered how you chain multiples of these together. We will get back to this in lesson 4 when we use color images. At this point, it's enough if you understand the kind of operation a convolutional filter performs
#
# * **output** `tf.keras.layers.Dense` — A 128-neuron, followed by 10-node *softmax* layer. Each node represents a class of clothing. As in the previous layer, the final layer takes input from the 128 nodes in the layer before it, and outputs a value in the range `[0, 1]`, representing the probability that the image belongs to that class. The sum of all 10 node values is 1.
#
# > Note: Using `softmax` activation and `SparseCategoricalCrossentropy()` has issues and which are patched by the `tf.keras` model. A safer approach, in general, is to use a linear output (no activation function) with `SparseCategoricalCrossentropy(from_logits=True)`.
#
#
# ### Compile the model
#
# Before the model is ready for training, it needs a few more settings. These are added during the model's *compile* step:
#
#
# * *Loss function* — An algorithm for measuring how far the model's outputs are from the desired output. The goal of training is this measures loss.
# * *Optimizer* —An algorithm for adjusting the inner parameters of the model in order to minimize loss.
# * *Metrics* —Used to monitor the training and testing steps. The following example uses *accuracy*, the fraction of the images that are correctly classified.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ## Train the model
#
# First, we define the iteration behavior for the train dataset:
# 1. Repeat forever by specifying `dataset.repeat()` (the `epochs` parameter described below limits how long we perform training).
# 2. The `dataset.shuffle(60000)` randomizes the order so our model cannot learn anything from the order of the examples.
# 3. And `dataset.batch(32)` tells `model.fit` to use batches of 32 images and labels when updating the model variables.
#
# Training is performed by calling the `model.fit` method:
# 1. Feed the training data to the model using `train_dataset`.
# 2. The model learns to associate images and labels.
# 3. The `epochs=5` parameter limits training to 5 full iterations of the training dataset, so a total of 5 * 60000 = 300000 examples.
#
# (Don't worry about `steps_per_epoch`, the requirement to have this flag will soon be removed.)

# %%
BATCH_SIZE = 32
train_dataset = train_dataset.cache().repeat().shuffle(num_train_examples).batch(BATCH_SIZE)
test_dataset = test_dataset.cache().batch(BATCH_SIZE)

# %%
EPOCH = 5

history = model.fit(train_dataset, epochs=EPOCH, steps_per_epoch=math.ceil(num_train_examples/BATCH_SIZE))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 36s 18ms/step - loss: 0.3898 - accuracy: 0.8594
# Epoch 2/5
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.2582 - accuracy: 0.9057
# Epoch 3/5
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.2138 - accuracy: 0.9207
# Epoch 4/5
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.1794 - accuracy: 0.9347
# Epoch 5/5
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.1570 - accuracy: 0.9429

# %% [markdown]
# As the model trains, the loss and accuracy metrics are displayed. This model reaches an accuracy of about 0.97 (or 97%) on the training data.

# %% [markdown]
# ## Evaluate accuracy
#
# Next, compare how the model performs on the test dataset. Use all examples we have in the test dataset to assess accuracy.

# %%
test_loss, test_accuracy = model.evaluate(test_dataset, steps=math.ceil(num_test_examples/32))
print('Accuracy on test dataset:', test_accuracy)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2516 - accuracy: 0.9157
# Accuracy on test dataset: 0.9157000184059143

# %% [markdown]
# As it turns out, the accuracy on the test dataset is smaller than the accuracy on the training dataset. This is completely normal, since the model was trained on the `train_dataset`. When the model sees images it has never seen during training, (that is, from the `test_dataset`), we can expect performance to go down.

# %% [markdown]
# ## Train and evaluate with the same set up but mechanized model

# %%
import sys
sys.path.append("..")

from mechanism.mechanized_sequential import MechanizedSequential
from mechanism.mechanized_sequential import Mechanism
mechanized_model = MechanizedSequential([
    tf.keras.layers.Conv2D(32, (3,3), padding='same', activation=tf.nn.relu,
                           input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2), strides=2),
    tf.keras.layers.Conv2D(64, (3,3), padding='same', activation=tf.nn.relu),
    tf.keras.layers.MaxPooling2D((2, 2), strides=2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
mechanized_model.choose_mech(Mechanism.GAUSSIAN)
mechanized_model.set_mechanism_para(sigma = 0.1)

mechanized_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'],
              run_eagerly = True)


gaussian_history = mechanized_model.fit(train_dataset, epochs = EPOCH, steps_per_epoch=math.ceil(num_train_examples/BATCH_SIZE))
# Out:
# Epoch 1/5
# In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#    1/1875 [..............................] - ETA: 9:13 - loss: 2.3191 - accuracy: 0.0625In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#    2/1875 [..............................] - ETA: 2:16 - loss: 2.3428 - accuracy: 0.0625In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#    3/1875 [..............................] - ETA: 2:11 - loss: 2.3112 - accuracy: 0.0833In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#    4/1875 [..............................] - ETA: 2:02 - loss: 2.2850 - accuracy: 0.1094In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#    6/1875 [..............................] - ETA: 1:49 - loss: 2.2330 - accuracy: 0.1094In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#    7/1875 [..............................] - ETA: 1:47 - loss: 2.2011 - accuracy: 0.1384In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#    8/1875 [..............................] - ETA: 1:45 - loss: 2.1848 - accuracy: 0.1484In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#    9/1875 [..............................] - ETA: 1:45 - loss: 2.1493 - accuracy: 0.1771In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   10/1875 [..............................] - ETA: 1:44 - loss: 2.1201 - accuracy: 0.2062In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   11/1875 [..............................] - ETA: 1:44 - loss: 2.0834 - accuracy: 0.2330In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   12/1875 [..............................] - ETA: 1:44 - loss: 2.0539 - accuracy: 0.2500In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   13/1875 [..............................] - ETA: 1:44 - loss: 2.0180 - accuracy: 0.2692In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   14/1875 [..............................] - ETA: 1:44 - loss: 1.9855 - accuracy: 0.2879In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   15/1875 [..............................] - ETA: 1:44 - loss: 1.9607 - accuracy: 0.2937In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   16/1875 [..............................] - ETA: 1:44 - loss: 1.9175 - accuracy: 0.3086In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   17/1875 [..............................] - ETA: 1:44 - loss: 1.8709 - accuracy: 0.3309In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   18/1875 [..............................] - ETA: 1:44 - loss: 1.8421 - accuracy: 0.3385In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   19/1875 [..............................] - ETA: 1:44 - loss: 1.8052 - accuracy: 0.3520In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   20/1875 [..............................] - ETA: 1:45 - loss: 1.7913 - accuracy: 0.3516In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#   21/1875 [..............................] - ETA: 1:45 - loss: 1.7561 - accuracy: 0.3601In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
#
- loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1844/1875 [============================>.] - ETA: 2s - loss: 0.2116 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1845/1875 [============================>.] - ETA: 1s - loss: 0.2116 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1846/1875 [============================>.] - ETA: 1s - loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1847/1875 [============================>.] - ETA: 1s - loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1848/1875 [============================>.] - ETA: 1s - loss: 0.2114 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1849/1875 [============================>.] - ETA: 1s - loss: 0.2114 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1850/1875 [============================>.] - ETA: 1s - loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1851/1875 [============================>.] - ETA: 1s - loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1852/1875 [============================>.] - ETA: 1s - loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1853/1875 [============================>.] - ETA: 1s - loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1854/1875 [============================>.] - ETA: 1s - loss: 0.2114 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1855/1875 [============================>.] - ETA: 1s - loss: 0.2114 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1856/1875 [============================>.] - ETA: 1s - loss: 0.2114 - accuracy: 0.9218In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1857/1875 [============================>.] - ETA: 1s - loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1858/1875 [============================>.] - ETA: 1s - loss: 0.2116 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1859/1875 [============================>.] - ETA: 1s - loss: 0.2116 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1861/1875 [============================>.] - ETA: 0s - loss: 0.2116 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1863/1875 [============================>.] - ETA: 0s - loss: 0.2116 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1865/1875 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9218In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1866/1875 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9218In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1867/1875 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9218In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9218In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9218In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9218In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9217In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.2114 - accuracy: 0.9218In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.2114 - accuracy: 0.9218In Gaussian Mechanism
# Create Gaussian noise when accessing the training data
# 1875/1875 [==============================] - 124s 66ms/step - loss: 0.2113 - accuracy: 0.9218

# %%
mechanized_model.choose_mech(None)
test_loss, test_accuracy = model.evaluate(test_dataset, steps=math.ceil(num_test_examples/32))
print('Accuracy on test dataset:', test_accuracy)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2516 - accuracy: 0.9157
# Accuracy on test dataset: 0.9157000184059143

# %%
mechanized_model.choose_mech(Mechanism.THRESHOLD)
mechanized_model.set_mechanism_para(sigma = 0.1, hold_frac = 0.4, threshold = 0.5)

mechanized_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'],
              run_eagerly = True)


threshold_history = mechanized_model.fit(train_dataset, epochs = EPOCH, steps_per_epoch=math.ceil(num_train_examples/BATCH_SIZE))
# Out:
# Epoch 1/5
# In Threshold out Mechanism
# 0.11454342
#    1/1875 [..............................] - ETA: 5:18 - loss: 1.5494 - accuracy: 0.9500In Threshold out Mechanism
# 0.05844477
#    2/1875 [..............................] - ETA: 2:06 - loss: 1.5731 - accuracy: 0.9000In Threshold out Mechanism
# 0.10320681
#    3/1875 [..............................] - ETA: 2:24 - loss: 1.5814 - accuracy: 0.8833In Threshold out Mechanism
# 0.09573876
#    4/1875 [..............................] - ETA: 2:42 - loss: 1.5829 - accuracy: 0.8875In Threshold out Mechanism
# 0.069202185
#    5/1875 [..............................] - ETA: 2:45 - loss: 1.5776 - accuracy: 0.8804In Threshold out Mechanism
# 0.08526336
#    6/1875 [..............................] - ETA: 2:36 - loss: 1.5706 - accuracy: 0.8846In Threshold out Mechanism
# 0.0644974
#    7/1875 [..............................] - ETA: 2:28 - loss: 1.5663 - accuracy: 0.8952In Threshold out Mechanism
# 0.11564007
#    8/1875 [..............................] - ETA: 2:22 - loss: 1.5559 - accuracy: 0.9097In Threshold out Mechanism
# 0.07644477
#    9/1875 [..............................] - ETA: 2:19 - loss: 1.5611 - accuracy: 0.9085In Threshold out Mechanism
# 0.099702775
#   10/1875 [..............................] - ETA: 2:16 - loss: 1.5551 - accuracy: 0.9130In Threshold out Mechanism
# 0.0817661
#   11/1875 [..............................] - ETA: 2:14 - loss: 1.5558 - accuracy: 0.9167In Threshold out Mechanism
# 0.09922187
#   12/1875 [..............................] - ETA: 2:25 - loss: 1.5495 - accuracy: 0.9241In Threshold out Mechanism
# 0.03486399
#   13/1875 [..............................] - ETA: 2:23 - loss: 1.5489 - accuracy: 0.9262In Threshold out Mechanism
# 0.11093805
#   14/1875 [..............................] - ETA: 2:21 - loss: 1.5471 - accuracy: 0.9280In Threshold out Mechanism
#  216/1875 [==>...........................] - ETA: 1:43 - loss: 1.5431 - accuracy: 0.9262In Threshold out Mechanism
# 0.07327315
#  217/1875 [==>...........................] - ETA: 1:43 - loss: 1.5431 - accuracy: 0.9263In Threshold out Mechanism
# 0.08527522
#  218/1875 [==>...........................] - ETA: 1:43 - loss: 1.5433 - accuracy: 0.9262In Threshold out Mechanism
# 0.0856757
#  219/1875 [==>...........................] - ETA: 1:43 - loss: 1.5434 - accuracy: 0.9258In Threshold out Mechanism
# 0.097543634
#  220/1875 [==>...........................] - ETA: 1:43 - loss: 1.5432 - accuracy: 0.9260In Threshold out Mechanism
# 0.12706871
#  221/1875 [==>...........................] - ETA: 1:43 - loss: 1.5433 - accuracy: 0.9258In Threshold out Mechanism
# 0.06502546
#  222/1875 [==>...........................] - ETA: 1:43 - loss: 1.5433 - accuracy: 0.9257In Threshold out Mechanism
# 0.098329276
#  223/1875 [==>...........................] - ETA: 1:42 - loss: 1.5430 - accuracy: 0.9261In Threshold out Mechanism
# 0.07835161
#  224/1875 [==>...........................] - ETA: 1:42 - loss: 1.5429 - accuracy: 0.9262In Threshold out Mechanism
# 0.09555933
#  225/1875 [==>...........................] - ETA: 1:42 - loss: 1.5431 - accuracy: 0.9258In Threshold out Mechanism
# 0.0788743
#  226/1875 [==>...........................] - ETA: 1:42 - loss: 1.5432 - accuracy: 0.9257In Threshold out Mechanism
# 0.09014612
#  227/1875 [==>...........................] - ETA: 1:42 - loss: 1.5433 - accuracy: 0.9256In Threshold out Mechanism
# 0.08619792
#  228/1875 [==>...........................] - ETA: 1:42 - loss: 1.5433 - accuracy: 0.9255In Threshold out Mechanism
# 0.09219681
#  229/1875 [==>...........................] - ETA: 1:42 - loss: 1.5438 - accuracy: 0.9251In Threshold out Mechanism
# 0.093721144
#  230/1875 [==>...........................] - ETA: 1:42 - loss: 1.5437 - accuracy: 0.9250In Threshold out Mechanism
# 0.10293673
#  231/1875 [==>...........................] - ETA: 1:41 - loss: 1.5437 - accuracy: 0.9249In Threshold out Mechanism
# 0.070358224
#  232/1875 [==>...........................] - ETA: 1:42 - loss: 1.5438 - accuracy: 0.9248In Threshold out Mechanism
# 0.08444475
#  233/1875 [==>...........................] - ETA: 1:42 - loss: 1.5439 - accuracy: 0.9247In Threshold out Mechanism
# 0.09192605
#  234/1875 [==>...........................] - ETA: 1:42 - loss: 1.5441 - accuracy: 0.9243In Threshold out Mechanism
# 0.095185466
#  235/1875 [==>...........................] - ETA: 1:41 - loss: 1.5439 - accuracy: 0.9247In Threshold out Mechanism
# 0.09829794
#  236/1875 [==>...........................] - ETA: 1:41 - loss: 1.5437 - accuracy: 0.9248In Threshold out Mechanism
# 0.0816445
#  237/1875 [==>...........................] - ETA: 1:41 - loss: 1.5437 - accuracy: 0.9247In Threshold out Mechanism
# 0.08010124
#  238/1875 [==>...........................] - ETA: 1:41 - loss: 1.5436 - accuracy: 0.9248In Threshold out Mechanism
# 0.05133059
#  239/1875 [==>...........................] - ETA: 1:41 - loss: 1.5434 - accuracy: 0.9251In Threshold out Mechanism
# 0.0646651
#  312/1875 [===>..........................] - ETA: 1:34 - loss: 1.5450 - accuracy: 0.9220In Threshold out Mechanism
# 0.089196675
#  313/1875 [====>.........................] - ETA: 1:34 - loss: 1.5449 - accuracy: 0.9221In Threshold out Mechanism
# 0.1328471
#  314/1875 [====>.........................] - ETA: 1:34 - loss: 1.5449 - accuracy: 0.9222In Threshold out Mechanism
# 0.071089074
#  315/1875 [====>.........................] - ETA: 1:34 - loss: 1.5448 - accuracy: 0.9223In Threshold out Mechanism
# 0.1040491
#  316/1875 [====>.........................] - ETA: 1:34 - loss: 1.5448 - accuracy: 0.9224In Threshold out Mechanism
# 0.11195562
#  317/1875 [====>.........................] - ETA: 1:34 - loss: 1.5447 - accuracy: 0.9223In Threshold out Mechanism
# 0.055643417
#  318/1875 [====>.........................] - ETA: 1:34 - loss: 1.5449 - accuracy: 0.9219In Threshold out Mechanism
# 0.06329785
#  319/1875 [====>.........................] - ETA: 1:34 - loss: 1.5447 - accuracy: 0.9222In Threshold out Mechanism
# 0.09897851
#  320/1875 [====>.........................] - ETA: 1:34 - loss: 1.5446 - accuracy: 0.9223In Threshold out Mechanism
# 0.083003074
#  321/1875 [====>.........................] - ETA: 1:34 - loss: 1.5446 - accuracy: 0.9224In Threshold out Mechanism
# 0.068811215
#  322/1875 [====>.........................] - ETA: 1:33 - loss: 1.5446 - accuracy: 0.9226In Threshold out Mechanism
# 0.052239664
#  323/1875 [====>.........................] - ETA: 1:33 - loss: 1.5448 - accuracy: 0.9222In Threshold out Mechanism
# 0.10274599
#  324/1875 [====>.........................] - ETA: 1:33 - loss: 1.5449 - accuracy: 0.9220In Threshold out Mechanism
# 0.066371076
#  325/1875 [====>.........................] - ETA: 1:33 - loss: 1.5448 - accuracy: 0.9221In Threshold out Mechanism
# 0.0468342
#  326/1875 [====>.........................] - ETA: 1:33 - loss: 1.5446 - accuracy: 0.9223In Threshold out Mechanism
# 0.069749385
#  327/1875 [====>.........................] - ETA: 1:33 - loss: 1.5445 - accuracy: 0.9222In Threshold out Mechanism
# 0.057920694
#  328/1875 [====>.........................] - ETA: 1:33 - loss: 1.5447 - accuracy: 0.9220In Threshold out Mechanism
# 0.09967934
#  329/1875 [====>.........................] - ETA: 1:33 - loss: 1.5444 - accuracy: 0.9223In Threshold out Mechanism
# 0.088267595
#  330/1875 [====>.........................] - ETA: 1:33 - loss: 1.5444 - accuracy: 0.9223In Threshold out Mechanism
# 0.08090442
#  331/1875 [====>.........................] - ETA: 1:33 - loss: 1.5444 - accuracy: 0.9224In Threshold out Mechanism
# 0.13408293
#  332/1875 [====>.........................] - ETA: 1:33 - loss: 1.5443 - accuracy: 0.9225In Threshold out Mechanism
# 0.094040625
#  333/1875 [====>.........................] - ETA: 1:32 - loss: 1.5442 - accuracy: 0.9226In Threshold out Mechanism
# 0.098466806
#  334/1875 [====>.........................] - ETA: 1:32 - loss: 1.5442 - accuracy: 0.9227In Threshold out Mechanism
# 0.054347944
#  335/1875 [====>.........................] - ETA: 1:32 - loss: 1.5442 - accuracy: 0.9228In Threshold out Mechanism
# 0.06547694
#  336/1875 [====>.........................] - ETA: 1:32 - loss: 1.5440 - accuracy: 0.9230In Threshold out Mechanism
# 0.11211934
#  337/1875 [====>.........................] - ETA: 1:32 - loss: 1.5440 - accuracy: 0.9229In Threshold out Mechanism
# 0.094605744
#  338/1875 [====>.........................] - ETA: 1:32 - loss: 1.5441 - accuracy: 0.9229In Threshold out Mechanism
# 0.08909446
#  339/1875 [====>.........................] - ETA: 1:32 - loss: 1.5443 - accuracy: 0.9227In Threshold out Mechanism
# 0.10186788
#  340/1875 [====>.........................] - ETA: 1:32 - loss: 1.5442 - accuracy: 0.9227In Threshold out Mechanism
# 0.070271
#  341/1875 [====>.........................] - ETA: 1:32 - loss: 1.5445 - accuracy: 0.9222In Threshold out Mechanism
# 0.104873225
#  342/1875 [====>.........................] - ETA: 1:32 - loss: 1.5445 - accuracy: 0.9221In Threshold out Mechanism
# 0.095895134
#  343/1875 [====>.........................] - ETA: 1:32 - loss: 1.5444 - accuracy: 0.9224In Threshold out Mechanism
# 0.065745994
#  344/1875 [====>.........................] - ETA: 1:32 - loss: 1.5441 - accuracy: 0.9226In Threshold out Mechanism
# 0.07073674
#  345/1875 [====>.........................] - ETA: 1:32 - loss: 1.5441 - accuracy: 0.9227In Threshold out Mechanism
# 0.10576739
#  346/1875 [====>.........................] - ETA: 1:31 - loss: 1.5441 - accuracy: 0.9228In Threshold out Mechanism
# 0.07922684
#  347/1875 [====>.........................] - ETA: 1:31 - loss: 1.5439 - accuracy: 0.9230In Threshold out Mechanism
# 0.0838055
#  348/1875 [====>.........................] - ETA: 1:31 - loss: 1.5441 - accuracy: 0.9228In Threshold out Mechanism
# 0.08628604
#  349/1875 [====>.........................] - ETA: 1:31 - loss: 1.5440 - accuracy: 0.9229In Threshold out Mechanism
# 0.106718995
#  350/1875 [====>.........................] - ETA: 1:31 - loss: 1.5441 - accuracy: 0.9227In Threshold out Mechanism
# 0.09720059
#  351/1875 [====>.........................] - ETA: 1:31 - loss: 1.5441 - accuracy: 0.9224In Threshold out Mechanism
# 0.07509653
#  352/1875 [====>.........................] - ETA: 1:31 - loss: 1.5440 - accuracy: 0.9225In Threshold out Mechanism
# 0.097899474
#  353/1875 [====>.........................] - ETA: 1:31 - loss: 1.5440 - accuracy: 0.9227In Threshold out Mechanism
# 0.09626397
#  354/1875 [====>.........................] - ETA: 1:31 - loss: 1.5439 - accuracy: 0.9228In Threshold out Mechanism
# 0.11284506
#  355/1875 [====>.........................] - ETA: 1:31 - loss: 1.5439 - accuracy: 0.9230In Threshold out Mechanism
# 0.08712304
#  356/1875 [====>.........................] - ETA: 1:31 - loss: 1.5441 - accuracy: 0.9228In Threshold out Mechanism
# 0.06749264
#  357/1875 [====>.........................] - ETA: 1:31 - loss: 1.5442 - accuracy: 0.9225In Threshold out Mechanism
# 0.0874504
#  358/1875 [====>.........................] - ETA: 1:31 - loss: 1.5443 - accuracy: 0.9223In Threshold out Mechanism
# 0.094229184
#  359/1875 [====>.........................] - ETA: 1:31 - loss: 1.5441 - accuracy: 0.9226In Threshold out Mechanism
# 0.10532291
#  360/1875 [====>.........................] - ETA: 1:30 - loss: 1.5439 - accuracy: 0.9228In Threshold out Mechanism
# 0.07947626
#  361/1875 [====>.........................] - ETA: 1:30 - loss: 1.5438 - accuracy: 0.9230In Threshold out Mechanism
# 0.10288288
#  362/1875 [====>.........................] - ETA: 1:30 - loss: 1.5438 - accuracy: 0.9229In Threshold out Mechanism
# 0.1054885
#  363/1875 [====>.........................] - ETA: 1:30 - loss: 1.5439 - accuracy: 0.
1875 [============================>.] - ETA: 4s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.06908726
# 1831/1875 [============================>.] - ETA: 4s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.050586034
# 1832/1875 [============================>.] - ETA: 4s - loss: 1.5270 - accuracy: 0.9352In Threshold out Mechanism
# 0.09182945
# 1833/1875 [============================>.] - ETA: 4s - loss: 1.5270 - accuracy: 0.9352In Threshold out Mechanism
# 0.08089265
# 1834/1875 [============================>.] - ETA: 4s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.084845886
# 1835/1875 [============================>.] - ETA: 4s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.05055215
# 1836/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.09279272
# 1837/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.07313421
# 1838/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.07528343
# 1839/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.114173695
# 1840/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.05111315
# 1841/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.0798149
# 1842/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.10588298
# 1843/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.11712842
# 1844/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.0900095
# 1845/1875 [============================>.] - ETA: 3s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.09206108
# 1846/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.06463201
# 1847/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.08152844
# 1848/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.097082436
# 1849/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.069231674
# 1850/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.09987664
# 1851/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.08947368
# 1852/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.085406564
# 1853/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.11315789
# 1854/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.06897454
# 1855/1875 [============================>.] - ETA: 2s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.037838615
# 1856/1875 [============================>.] - ETA: 1s - loss: 1.5270 - accuracy: 0.9351In Threshold out Mechanism
# 0.121519126
# 1857/1875 [============================>.] - ETA: 1s - loss: 1.5271 - accuracy: 0.9350In Threshold out Mechanism
# 0.07867393
# 1858/1875 [============================>.] - ETA: 1s - loss: 1.5271 - accuracy: 0.9350In Threshold out Mechanism
# 0.06734449
# 1859/1875 [============================>.] - ETA: 1s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.039770704
# 1860/1875 [============================>.] - ETA: 1s - loss: 1.5271 - accuracy: 0.9350In Threshold out Mechanism
# 0.10173863
# 1861/1875 [============================>.] - ETA: 1s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.095484935
# 1862/1875 [============================>.] - ETA: 1s - loss: 1.5271 - accuracy: 0.9350In Threshold out Mechanism
# 0.10151728
# 1863/1875 [============================>.] - ETA: 1s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.07935371
# 1864/1875 [============================>.] - ETA: 1s - loss: 1.5271 - accuracy: 0.9350In Threshold out Mechanism
# 0.08157511
# 1865/1875 [============================>.] - ETA: 1s - loss: 1.5270 - accuracy: 0.9350In Threshold out Mechanism
# 0.10701754
# 1866/1875 [============================>.] - ETA: 0s - loss: 1.5271 - accuracy: 0.9350In Threshold out Mechanism
# 0.08172049
# 1867/1875 [============================>.] - ETA: 0s - loss: 1.5271 - accuracy: 0.9350In Threshold out Mechanism
# 0.10126116
# 1868/1875 [============================>.] - ETA: 0s - loss: 1.5271 - accuracy: 0.9350In Threshold out Mechanism
# 0.09999982
# 1869/1875 [============================>.] - ETA: 0s - loss: 1.5271 - accuracy: 0.9349In Threshold out Mechanism
# 0.1319711
# 1870/1875 [============================>.] - ETA: 0s - loss: 1.5271 - accuracy: 0.9349In Threshold out Mechanism
# 0.10239738
# 1871/1875 [============================>.] - ETA: 0s - loss: 1.5271 - accuracy: 0.9349In Threshold out Mechanism
# 0.087905765
# 1872/1875 [============================>.] - ETA: 0s - loss: 1.5270 - accuracy: 0.9349In Threshold out Mechanism
# 0.098598994
# 1873/1875 [============================>.] - ETA: 0s - loss: 1.5270 - accuracy: 0.9349In Threshold out Mechanism
# 0.06636234
# 1874/1875 [============================>.] - ETA: 0s - loss: 1.5270 - accuracy: 0.9349In Threshold out Mechanism
# 0.07796466
# 1875/1875 [==============================] - 188s 100ms/step - loss: 1.5271 - accuracy: 0.9349

# %%
mechanized_model.choose_mech(None)
test_loss, test_accuracy = model.evaluate(test_dataset, steps=math.ceil(num_test_examples/32))
print('Accuracy on test dataset:', test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mechanized_model.choose_mech(None)
#       2 test_loss, test_accuracy = model.evaluate(test_dataset, steps=math.ceil(num_test_examples/32))
#       3 print('Accuracy on test dataset:', test_accuracy)
#
# NameError: name 'mechanized_model' is not defined

# %%
def visualization(history, mech="baseline"):
    acc = history.history['accuracy']
    # val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    # val_loss = history.history['val_loss']

    epochs_range = range(EPOCH)
    print(epochs_range)

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label= ('Training Accuracy-'+ mech))
    # plt.plot(epochs_range, val_acc, label=('Validation Accuracy-'+ mech))
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss-'+ mech)
    # plt.plot(epochs_range, val_loss, label='Validation Loss-'+ mech)
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

# %%
plt.figure(figsize=(8, 8))
visualization(history)
visualization(gaussian_history, "Gaussian")
visualization(threshold_history, "Threshold")
plt.show()
# Out:
# range(0, 5)
# range(0, 5)
# range(0, 5)
